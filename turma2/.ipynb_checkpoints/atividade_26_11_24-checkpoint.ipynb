# %%
 # Dados _ Penalidades aplicadas a operadoras

# O conjunto de dados não contempla as arrecadações a partir de maio de 2018 dos valores inscritos em Dívida, data em que 
# esses recebimentos passaram a ser controlados pelo SAPIENS, sistema utilizado pela Procuradoria-Geral Federal 
# Estão incluídos apenas os processos sancionadores nos quais foi aplicada multa em primeira ou segunda instância,
# mesmo que já tenha sido cancelada. Foram excluídos os pagamentos referentes às GRUs arrecadadas em Dívida Ativa.

# %%
# importando o pandas
import pandas as pd

# %%
# importando pacotes para graficos
import matplotlib.pyplot as plt

# %%
from datetime import date

# %%
import seaborn as sns

# %%
path = "C:/Users/rodrigo/Desktop/DATA-SCIENCE-E-BUSINESS-INTELLIGENCE/turma2/datasets/"

# %%
df_mark = pd.read_csv(path + 'penalidades_aplicadas_a_operadoras.csv',sep=';', encoding='ISO-8859-1')

# %%
# remover colunas em branco
df_cleaned = df_mark.dropna(axis=1)

# %%
df_mark.head()
# Out:
#    NR_DEMANDA           NR_PROCESSO TIPO_PROCESSO OBJETO  CD_OPERADORA  \
# 0     6041550  33910.024846/2024-15    Consumidor    NaN      359017.0
# 1     5423853  33910.013664/2022-49    Consumidor    NaN      359017.0
# 2     5735088  33910.039446/2022-34    Consumidor    NaN      359017.0
# 3      395120  33902.163358/2005-51    Consumidor    NaN      359556.0
# 4     5186750  33910.030421/2021-94    Consumidor    NaN      359017.0
#
#                  CNPJ                              RAZAO_SOCIAL  \
# 0  44.649.812/0001-38         Notre Dame Intermédica Saúde S.A.
# 1  44.649.812/0001-38         Notre Dame Intermédica Saúde S.A.
# 2  44.649.812/0001-38         Notre Dame Intermédica Saúde S.A.
# 3  36.184.695/0001-56  Massa Falida De Policlinica Amhavre Ltda
# 4  44.649.812/0001-38         Notre Dame Intermédica Saúde S.A.
#
#    SITUACAO_OPERADORA                   STATUS_DEMANDA DT_DECISAO_1A  \
# 0                 1.0                      Em Cobrança    30/09/2024
# 1                 1.0                        Arquivado    05/04/2024
# 2                 1.0  Aguardando Recurso da Operadora    17/09/2024
# 3                 2.0                      Em Cobrança    13/05/2009
# 4                 1.0                        Arquivado    20/09/2021
#
#   DT_PUBLICACAO_1A DT_PUBLICACAO_1A_FINAL  VL_MULTA_FIXA_1A  \
# 0       03/10/2024             03/10/2024             60000
# 1       05/04/2024             05/04/2024            240000
# 2       18/09/2024             18/09/2024             88000
# 3       14/05/2009             14/05/2009             12000
# 4       20/09/2021             20/09/2021             30000
#
#    VL_MULTA_DIARIA_1A  VL_TOTAL_APLICADO_1A DT_CIENCIA_RECONSIDERA_TOTAL  \
# 0                   0                 60000                          NaN
# 1                   0                240000                          NaN
# 2                   0                 88000                          NaN
# 3                   0                 12000                          NaN
# 4                   0                 30000                          NaN
#
#   DT_DECISAO_2A DT_PUBLICACAO_2A TIPO_DECISAO_2A  VL_MULTA_FIXA_2A  \
# 0           NaN              NaN             NaN                 0
# 1           NaN              NaN             NaN                 0
# 2           NaN              NaN             NaN                 0
# 3           NaN              NaN             NaN                 0
# 4           NaN              NaN             NaN                 0
#
#    VL_MULTA_DIARIA_2A  VL_TOTAL_APLICADO_2A  VL_MULTA_FINAL_APLICADA  \
# 0                   0                     0                    60000
# 1                   0                     0                   240000
# 2                   0                     0                    88000
# 3                   0                     0                    12000
# 4                   0                     0                    30000
#
#    VL_TOTAL_DESCONTOS DT_ARQUIVAMENTO  \
# 0             24000.0             NaN
# 1             96000.0      06/08/2024
# 2                 NaN             NaN
# 3                 NaN             NaN
# 4             12000.0      22/11/2021
#
#                            MOTIVO_ARQUIVAMENTO   TIPO_PENALIDADE  \
# 0                                          NaN  Multa Pecuniária
# 1  Decisão condenatória com pagamento de multa  Multa Pecuniária
# 2                                          NaN  Multa Pecuniária
# 3                                          NaN  Multa Pecuniária
# 4  Decisão condenatória com pagamento de multa  Multa Pecuniária
#
#   DT_SUSPENSAO_ADM DT_SUSPENSAO_JUD               NR_GRU DT_VENC_GRU  \
# 0              NaN              NaN  \t29410030008290592  21/11/2024
# 1              NaN              NaN  \t29410030007899760  13/05/2024
# 2              NaN              NaN                   \t         NaN
# 3              NaN              NaN       \t805006200674  28/06/2013
# 4              NaN              NaN  \t29410030005846377  25/10/2021
#
#      VL_GRU DE_SITUACAO_GRU DT_PAGTO_A_VISTA_ANS  VL_PAGO_A_VISTA_ANS  \
# 0   36000.0        Pendente                  NaN                  NaN
# 1  144000.0            Pago           08/05/2024             144000.0
# 2       NaN             NaN                  NaN                  NaN
# 3   18707.0        Pendente                  NaN                  NaN
# 4   18000.0            Pago           25/10/2021              18000.0
#
#   DT_VENC_1A_PARC_ANS  VL_PARCELAS_ANS_PAGAS STATUS_PARCELAMENTO DT_INSCRICAO  \
# 0                 NaN                    NaN                 NaN          NaN
# 1                 NaN                    NaN                 NaN          NaN
# 2                 NaN                    NaN                 NaN          NaN
# 3                 NaN                    NaN                 NaN   05/08/2013
# 4                 NaN                    NaN                 NaN          NaN
#
#   INSCRITO_DA ORIGEM_PAGAMENTO  NR_COMPETENCIA_CARGA
# 0         NAO              ANS                202410
# 1         NAO              ANS                202410
# 2         NAO              NaN                202410
# 3         SIM               DA                202410
# 4         NAO              ANS                202410

# %%
# Qual o valor total das multas aplicadas por operadora?
plt.figure(figsize=(10, 6))
sns.barplot(x='CD_OPERADORA', y='VL_TOTAL_APLICADO_1A', data=df_mark,  color='skyblue')
plt.title('Valor Total das Multas Aplicadas por Operadora')
plt.xlabel('Operadora')
plt.ylabel('Valor Total Aplicado (R$)')
plt.xticks(rotation=90)  # Para girar as labels das operadoras se necessário
plt.show()

# %%
# Qual o valor das multas fixas e diárias aplicadas pelas operadoras?
plt.figure(figsize=(10, 6))
df_melted = df_mark[['CD_OPERADORA', 'VL_MULTA_FIXA_1A', 'VL_MULTA_DIARIA_1A']].melt(id_vars='CD_OPERADORA', 
                                                                               value_vars=['VL_MULTA_FIXA_1A', 'VL_MULTA_DIARIA_1A'], 
                                                                               var_name='Tipo de Multa', 
                                                                               value_name='Valor')
sns.barplot(x='CD_OPERADORA', y='Valor', hue='Tipo de Multa', data=df_melted, palette='Set1')
plt.title('Multas Fixas e Diárias Aplicadas pelas Operadoras')
plt.xlabel('Operadora')
plt.ylabel('Valor da Multa (R$)')
plt.xticks(rotation=90)
plt.show()

# %%
# Substituir valores nulos na coluna 'RAZAO_SOCIAL' por 'Desconhecido'
df_mark['RAZAO_SOCIAL'] = df_mark['RAZAO_SOCIAL'].fillna('Desconhecido')

# Garantir que 'VL_TOTAL_APLICADO_1A' seja numérico e tratar valores inválidos
df_mark['VL_TOTAL_APLICADO_1A'] = pd.to_numeric(df_mark['VL_TOTAL_APLICADO_1A'], errors='coerce')

# Remover as linhas com valores nulos em 'VL_TOTAL_APLICADO_1A'
df_mark = df_mark.dropna(subset=['VL_TOTAL_APLICADO_1A'])

# Agrupar por 'RAZAO_SOCIAL' e somar as multas
df_agrupado = df_mark.groupby('RAZAO_SOCIAL')['VL_TOTAL_APLICADO_1A'].sum().reset_index()

# Ordenar para mostrar as 10 operadoras com maiores multas
df_agrupado = df_agrupado.sort_values(by='VL_TOTAL_APLICADO_1A', ascending=False).head(10)

# Criar o gráfico de barras verticais
plt.figure(figsize=(12, 8))  # Aumentei o tamanho da figura para acomodar os nomes longos
sns.barplot(x='RAZAO_SOCIAL', y='VL_TOTAL_APLICADO_1A', data=df_agrupado, color='skyblue')
plt.title('Razão Social Mais Multada (Top 10)')
plt.xlabel('Razão Social')
plt.ylabel('Valor Total da Multa (R$)')
plt.xticks(rotation=45, ha='right', fontsize=10)  # Rotaciona mais e ajusta o tamanho da fonte
plt.tight_layout()  # Ajusta automaticamente os espaços
plt.show()
